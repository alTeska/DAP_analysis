# %% [markdown]
# # Find Best Traces to Evaluate the Results

# %%
import os
import glob
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from dap.utils import obs_params, load_current
from dap import DAPcython

# %%
os.chdir('../')

# %%
from utils import calc_features_ramp, calc_features_step, find_spikes

# %% [markdown]
# ## Load the Data

# %% [markdown]
# #### Parameters

# %%
fname = 'dap_models_step_5_param_1x30.hdf'

df_steps = pd.read_hdf(fname, key='step_features')
df_ramps = pd.read_hdf(fname, key='ramp_features')
df_traces = pd.read_hdf(fname, key='param_traces')

# %%
df_traces.index.rename('id', inplace=True)
df_traces.reset_index(level=0, inplace=True)
df_traces.head(3)
# Out:
#      id   gbar_nap  gbar_leak    gbar_nat  gbar_kdr  gbar_hcn  distance_ramp  \
# 0   1x6  19.342252   1.027113  103.170545  3.240814  0.055903    3562.887008
# 1  1x1k   1.738837   0.103274   10.537310  1.634430  0.163430    1148.632046
# 2   1x8  16.783553   0.737801  149.256908  3.378672  0.043110     709.984867
#
#    distance_step  distance_sum  \
# 0    4657.013375   8219.900383
# 1    2252.839022   3401.471068
# 2    2815.108924   3525.093791
#
#                                          step_traces  \
# 0  [-75.01399912743267, -74.86335365216834, -74.7...
# 1  [-75.01110598757148, -75.20225868793119, -75.3...
# 2  [-74.99345348208719, -74.98923286091164, -74.9...
#
#                                          ramp_traces
# 0  [-75.01300479722246, -74.98687580198283, -74.9...
# 1  [-74.99674118485125, -75.03086130375084, -75.0...
# 2  [-74.99161811029848, -74.99906263568553, -75.0...

# %% [markdown]
# #### Original Data

# %%
data_dir = '/home/alteska/Desktop/LFI_DAP/data/rawData/2015_08_26b.dat'

# %%
# calculate DAP
# load the input data
Ir, vr, tr, t_onr, t_offr, dtr = load_current(data_dir, protocol='rampIV', ramp_amp=3.1)
Is, vs, ts, t_ons, t_offs, dts = load_current(data_dir, protocol='IV', ramp_amp=1)

# %% [markdown]
# ### Run Best Fit for Comparison

# %%
### Set up themodel
params, labels = obs_params(reduced_model=True)
dap = DAPcython(-75, params)
U = dap.simulate(dtr, tr, Ir)
U_step = dap.simulate(dts, ts, Is)

# %%
fig, ax  = plt.subplots(ncols=2, figsize=(30,7))
ax[0].plot(vr, label='data')
ax[0].plot(U, label='best')
ax[0].legend();

ax[1].plot(vs, label='data')
ax[1].plot(U_step, label='best');
ax[1].legend();

# %% [markdown]
# ## Calculate The Features

# %%
data_feat_ramp = calc_features_ramp(vr, tr, dtr, t_onr, t_offr)
data_feat_ramp
# Out:
# array([-74.9345 , 113.997  ,   0.73   , -59.96875,  14.21575,  19.73   ,
#         -0.75   ,   1.39   , -78.09375])

# %%
data_feat_step = calc_features_step(vs, ts, dts, t_ons, t_offs)
data_feat_step
# Out:
# array([-76.63358125, 0.06351057982730121, 48.0, 20.62173913043478,
#        6.066798921122928, 24,
#        array([254.6 , 258.4 , 264.6 , 275.95, 291.85, 309.  , 328.9 , 347.95,
#        367.45, 387.1 , 409.75, 432.15, 456.4 , 479.25, 504.55, 527.35,
#        552.55, 575.95, 600.95, 626.85, 651.45, 675.85, 703.5 , 728.9 ])],
#       dtype=object)

# %% [markdown]
# ## Create Comparison DF

# %% [markdown]
# #### Ramp Current

# %%
df_diff_ramps = df_ramps.copy() - data_feat_ramp
df_diff_ramps['sum'] = df_diff_ramps.sum(axis=1)
df_diff_ramps['sum'] = np.abs(df_diff_ramps['sum'])

df_diff_ramps.index.rename('id', inplace=True)
df_diff_ramps.reset_index(level=0, inplace=True)

# %% [markdown]
# #### Step Current

# %%
df_diff_steps = df_steps.dropna()
df_diff_steps.drop('spike_times_stim', axis=1, inplace=True)
df_diff_steps = df_diff_steps - data_feat_step[:-1]

df_diff_steps.index.rename('id', inplace=True)
df_diff_steps.reset_index(level=0, inplace=True)
df_diff_steps['sum'] = df_diff_steps.drop('spike_count', axis=1).sum(axis=1)
# Out:
# /home/alteska/anaconda3/envs/dap2/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ### Pick The Best For Both Currents

# %%
n = 2
df_best_ramps = df_diff_ramps.sort_values('sum').head(n)
df_best_steps = df_diff_steps.sort_values('spike_count').head(n)

# %% [markdown]
# ## Merge With DFTraces to Get the best Traces and Parameters

# %%
names=['id','gbar_nap','gbar_leak','gbar_nat','gbar_kdr','gbar_hcn','ramp_traces', 'step_traces']

# %%
df_best_ramp_tr = pd.merge(df_traces, df_best_ramps)[names]
df_best_ramp_tr.head(3)
# Out:
#      id   gbar_nap  gbar_leak    gbar_nat  gbar_kdr  gbar_hcn  \
# 0  1x39  15.451121   1.068316  165.590385  3.516230  0.054795
# 1  1x23  14.846420   1.036250  162.569796  3.388068  0.050267
#
#                                          ramp_traces  \
# 0  [-75.00190707130862, -74.99991605178914, -75.0...
# 1  [-74.98687013992779, -75.03204115686982, -75.0...
#
#                                          step_traces
# 0  [-75.01721176780092, -75.00840410830051, -75.0...
# 1  [-75.00450141301815, -75.02216024535687, -75.0...

# %%
df_best_step_tr = pd.merge(df_traces, df_best_steps)[names]
df_best_step_tr.head(3)
# Out:
#      id   gbar_nap  gbar_leak    gbar_nat  gbar_kdr  gbar_hcn  \
# 0  1x37  14.442994   1.032129  169.273078  3.453050  0.051531
# 1  1x27  11.542190   1.070013  172.120981  2.862942  0.053684
#
#                                          ramp_traces  \
# 0  [-74.9996134547085, -75.02300656531001, -75.02...
# 1  [-74.99745948984253, -75.02789366046399, -75.0...
#
#                                          step_traces
# 0  [-74.99682441390374, -75.05395442336598, -75.0...
# 1  [-74.99378068898605, -75.08514870322432, -75.2...

# %% [markdown]
# ## Visualize Best Results of Given Batch

# %% [markdown]
# ### Ramp Current

# %%
traces_ramp = df_best_ramp_tr.ramp_traces
traces_step = df_best_ramp_tr.step_traces
ids = df_best_ramp_tr.id

# %%
fig, ax = plt.subplots(ncols=2, figsize=(30, 7))

ax[0].plot(vr, c='r', label='data');
ax[0].plot(U, c='r', label='data');

ax[1].plot(vs, c='r--', label='data');
ax[1].plot(U_step, c='r--', label='data');

for i, tr in enumerate(traces_ramp): 
    n = ids[i]
    ax[0].plot(tr, alpha=0.7, label=n)

for i, tr in enumerate(traces_step): 
    n = ids[i]
    ax[1].plot(tr, alpha=0.7, label=n)
    
ax[0].legend()
ax[1].legend();
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fc12cb92ae8> (for post_execute):
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('-r', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/lines.py in draw(self, renderer)
#     750                 self._set_gc_clip(gc)
#     751
# --> 752                 lc_rgba = mcolors.to_rgba(self._color, self._alpha)
#     753                 gc.set_foreground(lc_rgba, isRGBA=True)
#     754
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 176         rgba = _to_rgba_no_colorcycle(c, alpha)
#     177         try:
#     178             _colors_full_map.cache[c, alpha] = rgba
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     218         except ValueError:
#     219             pass
# --> 220         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     221     # tuple color.
#     222     c = np.array(c)
#
# ValueError: Invalid RGBA argument: '-r'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('-r', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2047                         orientation=orientation,
#    2048                         dryrun=True,
# -> 2049                         **kwargs)
#    2050                     renderer = self.figure._cachedRenderer
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     508
#     509         """
# --> 510         FigureCanvasAgg.draw(self)
#     511         renderer = self.get_renderer()
#     512
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/lines.py in draw(self, renderer)
#     750                 self._set_gc_clip(gc)
#     751
# --> 752                 lc_rgba = mcolors.to_rgba(self._color, self._alpha)
#     753                 gc.set_foreground(lc_rgba, isRGBA=True)
#     754
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 176         rgba = _to_rgba_no_colorcycle(c, alpha)
#     177         try:
#     178             _colors_full_map.cache[c, alpha] = rgba
#
# ~/anaconda3/envs/dap2/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     218         except ValueError:
#     219             pass
# --> 220         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     221     # tuple color.
#     222     c = np.array(c)
#
# ValueError: Invalid RGBA argument: '-r'

# %% [markdown]
# ### Step Current

# %%
traces_ramp = df_best_step_tr.ramp_traces
traces_step = df_best_step_tr.step_traces
ids = df_best_step_tr.id

# %%
fig, ax = plt.subplots(ncols=2, figsize=(30, 7))

ax[0].plot(vr, c='r', label='data');
ax[1].plot(vs, c='r', label='data');

for i, tr in enumerate(traces_ramp): 
    n = ids[i]
    ax[0].plot(tr, alpha=0.7, label=n)

for i, tr in enumerate(traces_step): 
    n = ids[i]
    ax[1].plot(tr, alpha=0.7, label=n)
    
ax[0].legend()
ax[1].legend();
